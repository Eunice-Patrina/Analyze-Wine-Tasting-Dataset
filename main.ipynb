# %% [markdown]
# Load the Data Frame

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wines.csv")

# %% [markdown]
# How many wines have been given a rating of a 100 points?

# %%
len(df.loc[df['points']==100])
# Out:
# 19

# %% [markdown]
# What is the name of most expensive wine?

# %%
df.loc[df['price'] == df['price'].max()]['name'].squeeze()
# Out:
# 'Glamorosa Sensible'

# %% [markdown]
# Calculate the new column where you show the ratings in scale of 0 - 5. Floats are allowed

# %%
df['ratings'] = df['price'] / 20

# %% [markdown]
# create a price histogram for the wine that cost less than hundred

# %%
df.loc[df['price'] < 100]['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plot price horizontally against points vertically. Do you think ratings increase by price?

# %%
df.plot(x='price', y='points')
# Out:
# <AxesSubplot:xlabel='price'>
